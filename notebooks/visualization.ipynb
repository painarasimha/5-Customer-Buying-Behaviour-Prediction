# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
data = pd.read_csv('G:/Portfolio Projects/Data Science/05-Customer Buying Behavior Prediction/data/customer_data.csv')

# %%
data.columns
# Out:
# Index(['id', 'age', 'gender', 'income', 'education', 'region',
#        'loyalty_status', 'purchase_frequency', 'purchase_amount',
#        'product_category', 'promotion_usage', 'satisfaction_score'],
#       dtype='object')

# %%
# Using histogram to visualize 'age' feature.
plt.figure(figsize=(10,6))
sns.histplot(data['age'], kde=True, bins=30, color='green')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
df = pd.read_csv('G:/Portfolio Projects/Data Science/05-Customer Buying Behavior Prediction/data/train_data.csv')
df = df.drop('purchase_frequency', axis=1)

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), cmap='coolwarm', fmt='.2f',linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
